# %% [raw]
# #Mutltiple Linear Regression
# !pip install pandas
# !pip install scikit-learn

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
data = pd.read_csv('./datasets/house_data.csv')
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %%
all_features = list(data.columns.drop(['id', 'price', 'date']))
print(len(all_features))
X_full = data[all_features]
y_full = data['price']
# Out:
# 18

# %%
selector = SelectKBest(score_func=f_regression, k=5)
selector.fit(X_full, y_full)
# Out:
# SelectKBest(k=5, score_func=<function f_regression at 0x7bc4450c22a0>)

# %%
mask = selector.get_support()
top_features = X_full.columns[mask].tolist()
print('Selected Top 5 features: ', top_features)
X_selected = X_full[top_features]
# Out:
# Selected Top 5 features:  ['bathrooms', 'sqft_living', 'grade', 'sqft_above', 'sqft_living15']

# %%
X_train, X_test, y_train, y_test = train_test_split(X_selected, y_full, test_size=0.20, random_state=42)
print('Train Shape: ', X_train.shape)
print('Test Shape: ', X_test)
# Out:
# Train Shape:  (17290, 5)
# Test Shape:         bathrooms  sqft_living  grade  sqft_above  sqft_living15
# 735         2.25         2070      8        2070           2390
# 2830        3.00         2900      8        1830           2370
# 4106        2.50         3770     11        3770           3710
# 16218       3.50         4560     12        4560           4050
# 19964       2.50         2550      9        2550           2250
# ...          ...          ...    ...         ...            ...
# 13674       1.75         1250      7        1250           1340
# 20377       2.75         2830      8        2830           2160
# 8805        2.50         2434      8        2434           2434
# 10168       1.75         2250      8        2250           2050
# 2522        2.50         2570      8        2570           2430
#
# [4323 rows x 5 columns]

# %% [markdown]
# model = LinearRegression()
# model.fit(X_train, y_train)

# %%
y_predictions = model.predict(X_test)

# %%
print("Slope: ", model.coef_)
print("Intercept: ", model.intercept_)
print('R2 Score: ', r2_score(y_test, y_predictions))
print('Mean square error: ', mean_squared_error(y_test, y_predictions))
print('Mean absolute error: ', mean_absolute_error(y_test, y_predictions))
# Out:
# Slope:  [-3.17052494e+04  2.44972877e+02  1.08349319e+05 -8.13456415e+01
#   2.28602212e+01]
# Intercept:  -632600.0025421593
# R2 Score:  0.5480396608809947
# Mean square error:  68325878138.50519
# Mean absolute error:  164502.84240610639
